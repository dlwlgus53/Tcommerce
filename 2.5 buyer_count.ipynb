# %% [markdown]
# # 2.5 Add buy people count
# - 구매자 수 변수 생성
# - 판매 총 액/ 판매단가 = 구매자수

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('data/train_set/2.4pastAvg_diff.csv')

# %%
#buy_count is number of people who buy the product
data['buy_count'] = data['handling_amount']/data['unit_price']

# %%
# box plot of buyer
print(plt.boxplot(data['buy_count']))
# Out:
# {'whiskers': [<matplotlib.lines.Line2D object at 0x00000227F6BFE488>, <matplotlib.lines.Line2D object at 0x00000227F6BF8E88>], 'caps': [<matplotlib.lines.Line2D object at 0x00000227F6BFEF88>, <matplotlib.lines.Line2D object at 0x00000227F6BFEB88>], 'boxes': [<matplotlib.lines.Line2D object at 0x00000227F6BF8C48>], 'medians': [<matplotlib.lines.Line2D object at 0x00000227F71C3B08>], 'fliers': [<matplotlib.lines.Line2D object at 0x00000227F71C3FC8>], 'means': []}

# %% [markdown]
# ### 구매가 가장 적었던 상품

# %%
#find the min buyer
data.sort_values(by = 'buy_count').head(10)
# Out:
#             broadcast_date  broadcast_time  broadcast_code  product_code  \
# 30868  2019-11-13 02:00:00       20.000000          100076        200208
# 30867  2019-11-13 01:40:00       17.166667          100076        200209
# 19309  2019-07-16 00:20:00       20.000000          100153        200558
# 24533  2019-09-08 10:30:00       10.000000          100352        201144
# 27554  2019-10-08 10:30:00       30.100000          100787        202315
# 19311  2019-07-16 00:40:00       20.000000          100153        200558
# 27552  2019-10-08 10:00:00       30.100000          100787        202314
# 27549  2019-10-08 10:00:00       30.100000          100787        202313
# 27547  2019-10-08 10:00:00       30.100000          100787        202311
# 32725  2019-12-03 15:20:00       30.100000          100786        202309
#
#                       product_name product_category  unit_price  \
# 30868               (무)이누스바스 시공패키지               가구     2980000
# ...

# %% [markdown]
# ### 구매가 가장 많았던 상품

# %%
#find the min buyer

data.sort_values(by = 'buy_count', ascending = False).head(10)
# Out:
#             broadcast_date  broadcast_time  broadcast_code  product_code  \
# 33043  2019-12-07 01:40:00       17.166667          100418        201322
# 30659  2019-11-10 17:00:00       20.000000          100253        200864
# 34506  2019-12-21 17:40:00       20.000000          100418        201322
# 34971  2019-12-27 00:00:00       20.000000          100323        201025
# 31758  2019-11-22 19:00:00       20.000000          100317        201665
# 33494  2019-12-11 00:00:00       20.000000          100418        201322
# 34575  2019-12-22 17:00:00       20.000000          100074        201007
# 34854  2019-12-25 16:40:00       20.000000          100699        202064
# 32016  2019-11-25 22:00:00       20.000000          100074        200199
# 31836  2019-11-23 23:00:00       20.000000          100548        201634
#
#                    product_name product_category  unit_price  handling_amount  \
# 33043          코몽트 덤블 플리스 자켓 2종               의류       39900      322009000.0
# ...

# %%
# save the count
data.to_csv('data/train_set/2.5buyer_count.csv', index = False)
