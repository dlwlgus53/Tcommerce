# %% [markdown]
# ## 2.2 시청률 데이터 불러오기
# - test set에 대한 시청률은 존재하지 않는다.
# - 그래서 시청률 데이터를 바로 사용하기보다는, 시청률 데이터를 이용해 변수를 만든뒤에 이를 적용해야한다.
# - 19년도 12월 31일까지 시청률 데이터가 존재하기 때문에 기본 데이터에서 2020 1월데이터는 삭제하고 적절한 변수 만들기를 해야한다

# %%
import pandas as pd
watching = pd.read_excel('data/train_set/watching.xlsx', header = 1)
# 맨 마지막 row, column은 평균값
watching
# Out:
#                      시간대  2019-01-01  2019-01-02  2019-01-03  2019-01-04  \
# 0                  02:00       0.000       0.000       0.000       0.000
# 1                  02:01       0.000       0.000       0.000       0.000
# 2                  02:02       0.000       0.000       0.000       0.000
# 3                  02:03       0.000       0.000       0.014       0.000
# 4                  02:04       0.000       0.000       0.000       0.000
# ...                  ...         ...         ...         ...         ...
# 1436               01:56       0.000       0.000       0.000       0.000
# 1437               01:57       0.000       0.000       0.000       0.000
# 1438               01:58       0.000       0.000       0.000       0.000
# 1439               01:59       0.000       0.000       0.000       0.000
# 1440  월화수목금토일02:00-01:59       0.004       0.006       0.002       0.003
#
#       2019-01-05  2019-01-06  2019-01-07  2019-01-08  2019-01-09  ...  \
# ...

# %% [markdown]
# - 필요없는 행 제거

# %%
watching= watching.drop(columns = '2019-01-01 to 2019-12-31')[:-1]
watching
# Out:
#         시간대  2019-01-01  2019-01-02  2019-01-03  2019-01-04  2019-01-05  \
# 0     02:00         0.0         0.0       0.000         0.0       0.000
# 1     02:01         0.0         0.0       0.000         0.0       0.000
# 2     02:02         0.0         0.0       0.000         0.0       0.000
# 3     02:03         0.0         0.0       0.014         0.0       0.000
# 4     02:04         0.0         0.0       0.000         0.0       0.000
# ...     ...         ...         ...         ...         ...         ...
# 1435  01:55         0.0         0.0       0.000         0.0       0.000
# 1436  01:56         0.0         0.0       0.000         0.0       0.027
# 1437  01:57         0.0         0.0       0.000         0.0       0.000
# 1438  01:58         0.0         0.0       0.000         0.0       0.000
# 1439  01:59         0.0         0.0       0.000         0.0       0.000
#
#       2019-01-06  2019-01-07  2019-01-08  2019-01-09  ...  2019-12-22  \
# ...

# %%
watching = pd.melt(watching, id_vars=['시간대'], var_name='time', value_name='value')

# %%
watching['시간'] = watching['time'] +" "+ watching['시간대']
watching
# Out:
#           시간대        time  value                시간
# 0       02:00  2019-01-01    0.0  2019-01-01 02:00
# 1       02:01  2019-01-01    0.0  2019-01-01 02:01
# 2       02:02  2019-01-01    0.0  2019-01-01 02:02
# 3       02:03  2019-01-01    0.0  2019-01-01 02:03
# 4       02:04  2019-01-01    0.0  2019-01-01 02:04
# ...       ...         ...    ...               ...
# 525595  01:55  2019-12-31    0.0  2019-12-31 01:55
# 525596  01:56  2019-12-31    0.0  2019-12-31 01:56
# 525597  01:57  2019-12-31    0.0  2019-12-31 01:57
# 525598  01:58  2019-12-31    0.0  2019-12-31 01:58
# 525599  01:59  2019-12-31    0.0  2019-12-31 01:59
#
# [525600 rows x 4 columns]

# %%
watching = watching.drop(columns = ['time','시간대'])
watching['시간'] = pd.to_datetime(watching['시간'])
watching = watching.sort_values('시간')
watching = watching.set_index(['시간'], drop = True)

# %% [markdown]
# - melt함수로 사용하기 편리해진 watching csv 정리

# %%
watching.to_csv('data/train_set/watching_pivot.csv',index = False)

# %% [markdown]
# - 2020 년도를 제외한 data 읽어오기

# %%
data = pd.read_csv('data/train_set/2.data_add_feature1.csv', header = 0)
data = data.sort_values(['broadcast_date']).reset_index(drop=True)
data = data.loc[~data['broadcast_date'].str.contains('2020-01-01')]
data
# Out:
#             broadcast_date  broadcast_time  broadcast_code  product_code  \
# 0      2019-01-01 06:00:00            20.0          100346        201072
# 1      2019-01-01 06:00:00            20.0          100346        201079
# 2      2019-01-01 06:20:00            20.0          100346        201072
# 3      2019-01-01 06:20:00            20.0          100346        201079
# 4      2019-01-01 06:40:00            20.0          100346        201072
# ...                    ...             ...             ...           ...
# 37363  2019-12-31 23:20:00            20.0          100448        201391
# 37364  2019-12-31 23:40:00            20.0          100448        201391
# 37365  2019-12-31 23:40:00            20.0          100448        201384
# 37366  2019-12-31 23:40:00            20.0          100448        201383
# 37367  2019-12-31 23:40:00            20.0          100448        201390
#
#          product_name product_category  unit_price  handling_amount  off_day  \
# ...

# %% [markdown]
# - getmax,get avg 로 방송 당, 평균, 최대 시청률 구하기

# %%
def get_max(df):
    start = df['broadcast_date']
    delta = df['broadcast_time']
    end = (pd.to_datetime(start) + timedelta(minutes=int(delta)))
    if(end >= pd.to_datetime('2020-01-01 00:00')):
         end = (pd.to_datetime(start) + timedelta(minutes=int(delta-1)))
    return watching.loc[start:end,'value'].max()

# %%
from datetime import datetime, timedelta
data['broadcast_date'] = pd.to_datetime(data['broadcast_date'])
data['max_watching'] = data.apply(get_max, axis =  1)

# %%
import sys
import pdb
def get_avg(df):
    start = df['broadcast_date']
    delta = df['broadcast_time']
    end = (pd.to_datetime(start) + timedelta(minutes=int(delta)))
    if(end >= pd.to_datetime('2020-01-01 00:00')):
         end = (pd.to_datetime(start) + timedelta(minutes=int(delta-1)))
    return watching.loc[start:end,'value'].mean()
data['avg_watching'] = data.apply(get_avg, 1)

# %%
data.loc[data['max_watching'].isnull()]
data
# Out:
#            broadcast_date  broadcast_time  broadcast_code  product_code  \
# 0     2019-01-01 06:00:00            20.0          100346        201072
# 1     2019-01-01 06:00:00            20.0          100346        201079
# 2     2019-01-01 06:20:00            20.0          100346        201072
# 3     2019-01-01 06:20:00            20.0          100346        201079
# 4     2019-01-01 06:40:00            20.0          100346        201072
# ...                   ...             ...             ...           ...
# 37363 2019-12-31 23:20:00            20.0          100448        201391
# 37364 2019-12-31 23:40:00            20.0          100448        201391
# 37365 2019-12-31 23:40:00            20.0          100448        201384
# 37366 2019-12-31 23:40:00            20.0          100448        201383
# 37367 2019-12-31 23:40:00            20.0          100448        201390
#
#          product_name product_category  unit_price  handling_amount  off_day  \
# ...

# %%
data.to_csv('data/train_set/2.2data_weather_watching.csv',index = False)

# %%
data = pd.read_csv('data/train_set/2.2data_weather_watching.csv')
data
# Out:
#             broadcast_date  broadcast_time  broadcast_code  product_code  \
# 0      2019-01-01 06:00:00            20.0          100346        201072
# 1      2019-01-01 06:00:00            20.0          100346        201079
# 2      2019-01-01 06:20:00            20.0          100346        201072
# 3      2019-01-01 06:20:00            20.0          100346        201079
# 4      2019-01-01 06:40:00            20.0          100346        201072
# ...                    ...             ...             ...           ...
# 37363  2019-12-31 23:20:00            20.0          100448        201391
# 37364  2019-12-31 23:40:00            20.0          100448        201391
# 37365  2019-12-31 23:40:00            20.0          100448        201384
# 37366  2019-12-31 23:40:00            20.0          100448        201383
# 37367  2019-12-31 23:40:00            20.0          100448        201390
#
#          product_name product_category  unit_price  handling_amount  off_day  \
# ...

# %% [markdown]
# ### clustering
# https://jakevdp.github.io/PythonDataScienceHandbook/05.11-k-means.html
# https://bcho.tistory.com/1205

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()  # for plot styling
import numpy as np

# %%
from sklearn.datasets import make_blobs
from sklearn.preprocessing import LabelEncoder

X, y_true = make_blobs(n_samples=300, centers=4,
                       cluster_std=0.60, random_state=0)
# print(type(X))
encoder = LabelEncoder()
product_encoding =encoder.fit_transform(data['상품군'])/10 

X = np.array(list(map(list,zip(product_encoding,data['avg_watching']))))
# print(X[:,0])
plt.scatter(X[:, 0], X[:, 1], s=5);

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=4)
kmeans.fit(X)
y_kmeans = kmeans.predict(X)

# %%
plt.scatter(X[:, 0], X[:, 1], c=y_kmeans, s=50, cmap='viridis')

centers = kmeans.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5);

# %%
from sklearn.metrics import pairwise_distances_argmin

def find_clusters(X, n_clusters, rseed=2):
    # 1. Randomly choose clusters
    rng = np.random.RandomState(rseed)
    i = rng.permutation(X.shape[0])[:n_clusters]
    centers = X[i]
    
    while True:
        # 2a. Assign labels based on closest center
        labels = pairwise_distances_argmin(X, centers)
        
        # 2b. Find new centers from means of points
        new_centers = np.array([X[labels == i].mean(0)
                                for i in range(n_clusters)])
        
        # 2c. Check for convergence
        if np.all(centers == new_centers):
            break
        centers = new_centers
    
    return centers, labels

centers, labels = find_clusters(X, 4)
plt.scatter(X[:, 0], X[:, 1], c=labels,
            s=50, cmap='viridis');
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-46-85fb06f01e41> in <module>
#      22     return centers, labels
#      23
# ---> 24 centers, labels = find_clusters(X, 4)
#      25 plt.scatter(X[:, 0], X[:, 1], c=labels,
#      26             s=50, cmap='viridis');
#
# <ipython-input-46-85fb06f01e41> in find_clusters(X, n_clusters, rseed)
#       4     # 1. Randomly choose clusters
#       5     rng = np.random.RandomState(rseed)
# ----> 6     i = rng.permutation(X.shape[0])[:n_clusters]
#       7     centers = X[i]
#       8
#
# AttributeError: 'list' object has no attribute 'shape'
